# %%
import pandas as pd

# %%
dat = pd.read_csv('complete.csv'); dat
# Out:
#                  Id          Label  timeset  componentnumber  strongcompnum  \
# 0      SteveSarian1   SteveSarian1      NaN                0            641
# 1       Bij88941056    Bij88941056      NaN                0            634
# 2      lewinskylou2   lewinskylou2      NaN                0            307
# 3        DerrickDuc     DerrickDuc      NaN                0            634
# 4       Harm_Zwiers    Harm_Zwiers      NaN                0            634
# ...             ...            ...      ...              ...            ...
# 3049     vossejongk     vossejongk      NaN                0           2578
# 3050    YvonnePtwit    YvonnePtwit      NaN                0           2579
# 3051   Paulien_2014   Paulien_2014      NaN                0            634
# 3052      robertwve      robertwve      NaN                0           2580
# 3053  HarriePetille  HarriePetille      NaN                0           2581
#
# ...

# %%
dat['componentnumber'].value_counts()
# Out:
# 0    3054
# Name: componentnumber, dtype: int64

# %%
dat['Id'].value_counts()
# Out:
# SteveSarian1      1
# AsjeBello         1
# PubliekeOmroep    1
# dit_is_M          1
# p0lic0rrupt       1
#                  ..
# EvaReports        1
# TheDawn3121       1
# cpt_caveman_nl    1
# DuMonde88         1
# HarriePetille     1
# Name: Id, Length: 3054, dtype: int64
